# %% [markdown]
# <a href="https://colab.research.google.com/github/paakwow/SNA2-Final-Project/blob/main/Final_SNA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # We start loading a few useful *libraries*

# %%
import pandas as pd
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
import pandas as pd 

# Input data files are available in the "/content/drive/MyDrive/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/organization.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/organization.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import json
import os,re

# %%
import networkx as nx

# %%
data=pd.read_csv('/content/drive/MyDrive/organization.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-34b0399ceb8a> in <cell line: 1>()
# ----> 1 data=pd.read_csv('/content/drive/MyDrive/organization.csv')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from networkx.algorithms import bipartite
B=nx.Graph()
B.add_nodes_from(data['Organisation'],bipartite=0)
B.add_nodes_from(data['member'],bipartite=1)
for i in range(len(data)):
  B.add_edges_from([(data.iloc[i,1],data.iloc[i,0])])
# nx.draw(B,with_labels=1)
plt.figure(figsize=(25,25))
nx.draw(B, with_labels=True, node_size=1)
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24034 (\N{CJK UNIFIED IDEOGRAPH-5DE2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 40527 (\N{CJK UNIFIED IDEOGRAPH-9E4F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38463 (\N{CJK UNIFIED IDEOGRAPH-963F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from current font.
# ...

# %%
cc=nx.closeness_centrality(B, u=None, distance=None, wf_improved=True)
cc
# Out:
# {'ethereum': 0.3258929067749012,
#  'pytorch': 0.3252680383695806,
#  'udacity': 0.3242398441734553,
#  'firebase': 0.3250522956954464,
#  'flutter': 0.325724436916883,
#  'deepmind': 0.32459777747214547,
#  'reactjs': 0.32758724006918544,
#  'huggingface': 0.3266168987182696,
#  'google': 0.348088911711113,
#  'docker': 0.0020181634712411706,
#  'apache': 0.3538983070120768,
#  'vuejs': 0.3255080885823995,
#  'freeCodeCamp': 0.3258929067749012,
#  'airbnb': 0.3247411721610597,
#  'golang': 0.3255801727534888,
#  'nodejs': 0.33704987011244936,
#  'elastic': 0.3282210597031934,
#  'laravel': 0.0012333221213140487,
#  'aws': 0.3281966366762046,
#  'Azure': 0.3725198142138102,
#  'reduxjs': 0.1975825202836318,
#  'NVIDIA': 0.20698458868513364,
#  'redis': 0.0005606009642336585,
#  'rails': 0.24770496463503947,
#  'grafana': 0.32610976711952033,
#  'jquery': 0.24426175999842237,
#  'ansible': 0.19901789550995003,
#  'graphql': 0.1976179309239443,
#  'babel': 0.32719841248453363,
# ...

# %%
cliques=nx.find_cliques(B)
for cl in cliques:
  print(cl)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['Kishore Gopalakrishna', 'apache']
# ['Ben Hong', 'vuejs']
# ['Antoine Toulme', 'apache']
# ['Andriy Redko', 'apache']
# ['Edoardo Tenani', 'elastic']
# ['Sakthi', 'apache']
# ['Mark Struberg', 'apache']
# ['Christine Koppelt', 'apache']
# ['Mika', 'python']
# ['Brandon DeRosier', 'flutter']
# ['Chris Mark', 'elastic']
# ['David Lazar', 'golang']
# ['Constance', 'elastic']
# ['bitcoin', 'Antoine Poinsot']
# ['bitcoin', 'Sjors Provoost']
# ['bitcoin', 'Antoine Riard']
# ['bitcoin', 'Andrew Chow']
# ['bitcoin', 'Ben Woosley']
# ['bitcoin', 'Neha Narula']
# ['bitcoin', 'MacroFake']
# ['bitcoin', 'None']
# ['Asxing Yang（阿行）', 'apache']
# ['Junichi Yamamoto', 'apache']
# ['Keqiu Hu', 'apache']
# ['Henrik K', 'apache']
# ['Eric Dobbs', 'apache']
# ['Mars Hall', 'apache']
# ['Matt Clay', 'ansible']
# ['Xiangdong Huang', 'apache']
# ['Jia Yu', 'apache']
# ['Tom Chiverton', 'apache']
# ['Ezio Melotti', 'python']
# ...

# %%
max_clique_biparti=nx.make_clique_bipartite(B, fpos=None, create_using=None, name=None)
options = {"edgecolors": "black", "node_size": 100, "alpha": 0.9}

# Use the "with" statement to turn off the axis display
with plt.style.context("seaborn-white"):
    nx.draw(max_clique_biparti, node_color="yellow", **options)
    plt.show()

# %% [markdown]
# the nodes at the bottom left corner don't seem to have any links because probably when we turned of axis display in the code box above using seaborn-white, it may have affected their links/connections.

# %%
lb=nx.local_bridges(B)
sum=0
for bridge in lb:
    sum=sum+1
print("Number of Local Bridges are:",sum)
# Out:
# Number of Local Bridges are: 9656
